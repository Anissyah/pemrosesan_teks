# %%
# install library
! pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.6 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
# import library
from google_play_scraper import  Sort, reviews_all
from google_play_scraper import reviews
from google_play_scraper import app

# import pandas yang digunakan untuk analisis dan manipulasi data
import pandas as pd

# import numpy yang digunakan untuk memproses array multidimensi
import numpy as np

# %%
# mulai scraping
result, continuation_token = reviews(
    'com.ruangguru.livestudents',
    lang='id', #bahasa indonesia
    country='id', #negara indonesia
    sort=Sort.MOST_RELEVANT, #sorting yang paling relevan
    count=1000, #jumlah dataset
    filter_score_with=None #mulai scraping: 1,2,3,4,5, jadi nanti none nya bisa di ganti mau bintang berapa
)

# %%
# membuat Dataframe dari hasil scraping
data = pd.DataFrame(np.array(result),columns=['review'])

data = data.join(pd.DataFrame(data.pop('review').tolist()))

data #menampilkan semua data
# Out:
#                                  reviewId                userName  \
# 0    924c87f5-d5e1-49b7-8d0c-93e5005b4877    Aji Abdillah Mursyid
# 1    a5529b81-f622-4f5a-a1d2-f77048bd4094   Keysyah radiah Amanah
# 2    85011ad4-0437-4310-bebe-c51f54708515         Renata Pasaribu
# 3    f808a83d-449d-46b2-98c0-cd9c3be13672  Aisyah wardatul Jannah
# 4    545a6f5e-a46c-44eb-b3c3-6271d48d6d63  Dinar hafizah berliani
# ..                                    ...                     ...
# 995  32040f47-e403-4b9c-af9c-8473f0866158           Adiyatma Rafi
# 996  9c74cc5d-5a76-4d5a-97c0-4256a785cec2           Adelia Zafira
# 997  a144ceb8-912a-48da-87e0-86c6dda6f010         Pengguna Google
# 998  aeedf06a-3b6d-4c74-8a58-4057dfc634e3         Pengguna Google
# 999  cd2994ee-7655-41bd-93fe-391b0b8a5798         Cci 1 Tas Batam
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a/ACg8oc...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a/ACg8oc...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 997  https://play-lh.googleusercontent.com/EGemoI2N...
# 998  https://play-lh.googleusercontent.com/EGemoI2N...
# 999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0    terkadang ketika di pembahasan angkanya itu te...      4              1
# 1    Aplikasi belajar terbaik sejauh ini! Materinya...      5            236
# 2    aplikasinya sangat menyenangkan bisa langsung ...      5            228
# 3    worth it bgt sih, walau pun online, tapi tetep...      5             52
# 4    jujur aplikasinya lumayan membantu aku buat me...      5            206
# ..                                                 ...    ...            ...
# 995  •sesudah liat satu materi,mau lanjut ke Vidio ...      5              0
# 996  Semua materi ada, untuk semua kurikulum.. Teru...      5             67
# 997  Ini gimana ya kok saya tidak bisa mencoba lati...      2              0
# 998  Saya senang dengan update terbaru ruangguru de...      4              1
# 999  Suka banget💛 Pembahasan mudah dimengerti karen...      5              4
#
#     reviewCreatedVersion                  at  \
# 0                  7.0.4 2025-10-02 19:22:25
# 1                 6.99.0 2025-08-18 03:34:09
# 2                 6.99.0 2025-08-03 07:22:33
# 3                  7.0.4 2025-09-27 14:39:54
# 4                  7.0.2 2025-09-02 02:14:10
# ..                   ...                 ...
# 995                 None 2020-07-19 04:55:49
# 996               6.11.0 2021-04-04 10:09:15
# 997                 None 2019-12-03 12:20:23
# 998                 None 2018-10-23 12:09:15
# 999               5.10.0 2020-08-23 02:59:57
#
#                                           replyContent           repliedAt  \
# 0    Maaf ya kalau angka atau huruf di pembahasan t... 2025-10-03 03:47:25
# 1    Hai Keysyah, terima kasih banyak sudah kasih b... 2025-08-18 04:40:49
# 2    Wah senang banget dengarnya! Makasih ya Renata... 2025-08-05 07:51:11
# 3    Thanks Aisyah, atas saran dan apresiasi bintan... 2025-09-28 11:12:20
# 4    Wihh keren banget semangat belajarnya Dinar! M... 2025-09-03 03:19:08
# ..                                                 ...                 ...
# 995  Hai. Mohon maaf atas kendala yang dialami. Yuk... 2020-08-06 14:11:40
# 996  Hai Adelia, terima kasih atas apresiasi yang k... 2021-04-04 10:20:19
# 997  Hai Yoga. Terima kasih sudah menggunakan Aplik... 2019-12-03 12:26:51
# 998  Halo Jupri, terimakasih sudah memberikan revie... 2018-10-29 03:02:49
# 999  Hai, terima kasih sudah mempercayakan Ruanggur... 2020-09-26 01:17:05
#
#     appVersion
# 0        7.0.4
# 1       6.99.0
# 2       6.99.0
# 3        7.0.4
# 4        7.0.2
# ..         ...
# 995       None
# 996     6.11.0
# 997       None
# 998       None
# 999     5.10.0
#
# [1000 rows x 11 columns]

# %%
# Fungsi case folding
data['content_casefold'] = data['content'].astype(str).str.lower()

# %%
# Simpan ke CSV
data.to_csv("ruangguru_reviews.csv", index=False, encoding='utf-8-sig')
